# %% [markdown]
# # Exploratory Data Analysis

# %%
import csv
import pandas as pd

# %%
path_train = 'data/sts-train.csv'
path_dev = 'data/sts-dev.csv'
path_test = 'data/sts-test.csv'

# %%
columns=['genre', 'file', 'year', 'index', 'score', 'sentence1', 'sentence2']

# %%
df_train = pd.read_csv(path_train, sep='\t', usecols=range(7), header=None, quoting=csv.QUOTE_NONE, names=columns, encoding='UTF-8')
df_dev = pd.read_csv(path_dev, sep='\t', usecols=range(7), header=None, quoting=csv.QUOTE_NONE, names=columns, encoding='UTF-8')
df_test = pd.read_csv(path_test, sep='\t', usecols=range(7), header=None, quoting=csv.QUOTE_NONE, names=columns, encoding='UTF-8')

# %%
df = pd.concat([df_train, df_dev, df_test])
df
# Out:
#               genre       file      year  index  score
# 0     main-captions     MSRvid  2012test      1   5.00  \
# 1     main-captions     MSRvid  2012test      4   3.80
# 2     main-captions     MSRvid  2012test      5   3.80
# 3     main-captions     MSRvid  2012test      6   2.60
# 4     main-captions     MSRvid  2012test      9   4.25
# ...             ...        ...       ...    ...    ...
# 1374      main-news  headlines      2016   1354   0.00
# 1375      main-news  headlines      2016   1360   1.00
# 1376      main-news  headlines      2016   1368   1.00
# 1377      main-news  headlines      2016   1420   0.00
# 1378      main-news  headlines      2016   1432   0.00
#
#                                               sentence1
# 0                                A plane is taking off.  \
# 1                       A man is playing a large flute.
# 2         A man is spreading shreded cheese on a pizza.
# 3                          Three men are playing chess.
# 4                           A man is playing the cello.
# ...                                                 ...
# 1374  Philippines, Canada pledge to further boost re...
# 1375  Israel bars Palestinians from Jerusalem's Old ...
# 1376         How much do you know about Secret Service?
# 1377  Obama Struggles to Soothe Saudi Fears As Iran ...
# 1378          South Korea declares end to MERS outbreak
#
#                                               sentence2
# 0                           An air plane is taking off.
# 1                             A man is playing a flute.
# 2     A man is spreading shredded cheese on an uncoo...
# 3                            Two men are playing chess.
# 4                    A man seated is playing the cello.
# ...                                                 ...
# 1374            Philippines saves 100 after ferry sinks
# 1375  Two-state solution between Palestinians, Israe...
# 1376  Lawmakers from both sides express outrage at S...
# 1377  Myanmar Struggles to Finalize Voter Lists for ...
# 1378  North Korea Delegation Meets With South Korean...
#
# [8628 rows x 7 columns]

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# Check for the presence of null values:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8628 entries, 0 to 1378
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   genre      8628 non-null   object
#  1   file       8628 non-null   object
#  2   year       8628 non-null   object
#  3   index      8628 non-null   int64
#  4   score      8628 non-null   float64
#  5   sentence1  8628 non-null   object
#  6   sentence2  8628 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 539.2+ KB

# %% [markdown]
# There are no null values.

# %%
df['genre'].value_counts()
# Out:
# genre
# main-news        4299
# main-captions    3250
# main-forums       629
# main-forum        450
# Name: count, dtype: int64

# %%
df['genre'] = df['genre'].replace('main-', '', regex=True)
df['genre'] = df['genre'].replace('forum', 'forums')

# %%
df['genre'].value_counts()
# Out:
# genre
# news        4299
# captions    3250
# forums      1079
# Name: count, dtype: int64

# %%
df['year'].value_counts()
# Out:
# year
# 2014         2250
# 2015         1875
# 2012test     1500
# 2012train    1500
# 2013          750
# 2016          503
# 2017          250
# Name: count, dtype: int64

# %%
# Remove everything in this column which is not a number
df['year'] = df['year'].replace(r'\D', '', regex=True)

# %%
df['year'].value_counts()
# Out:
# year
# 2012    3000
# 2014    2250
# 2015    1875
# 2013     750
# 2016     503
# 2017     250
# Name: count, dtype: int64

# %% [markdown]
# ## Dataset Analysis

# %%
df
# Out:
#          genre       file  year  index  score
# 0     captions     MSRvid  2012      1   5.00  \
# 1     captions     MSRvid  2012      4   3.80
# 2     captions     MSRvid  2012      5   3.80
# 3     captions     MSRvid  2012      6   2.60
# 4     captions     MSRvid  2012      9   4.25
# ...        ...        ...   ...    ...    ...
# 1374      news  headlines  2016   1354   0.00
# 1375      news  headlines  2016   1360   1.00
# 1376      news  headlines  2016   1368   1.00
# 1377      news  headlines  2016   1420   0.00
# 1378      news  headlines  2016   1432   0.00
#
#                                               sentence1
# 0                                A plane is taking off.  \
# 1                       A man is playing a large flute.
# 2         A man is spreading shreded cheese on a pizza.
# 3                          Three men are playing chess.
# 4                           A man is playing the cello.
# ...                                                 ...
# 1374  Philippines, Canada pledge to further boost re...
# 1375  Israel bars Palestinians from Jerusalem's Old ...
# 1376         How much do you know about Secret Service?
# 1377  Obama Struggles to Soothe Saudi Fears As Iran ...
# 1378          South Korea declares end to MERS outbreak
#
#                                               sentence2
# 0                           An air plane is taking off.
# 1                             A man is playing a flute.
# 2     A man is spreading shredded cheese on an uncoo...
# 3                            Two men are playing chess.
# 4                    A man seated is playing the cello.
# ...                                                 ...
# 1374            Philippines saves 100 after ferry sinks
# 1375  Two-state solution between Palestinians, Israe...
# 1376  Lawmakers from both sides express outrage at S...
# 1377  Myanmar Struggles to Finalize Voter Lists for ...
# 1378  North Korea Delegation Meets With South Korean...
#
# [8628 rows x 7 columns]

# %%
print(f'Total number of sentences: {df.shape[0]*2}')
# Out:
# Total number of sentences: 17256

# %% [markdown]
# Lengths of sentences (n° characters):

# %%
s1_len = df['sentence1'].apply(lambda x : len(str(x)))
s2_len = df['sentence2'].apply(lambda x : len(str(x)))

print(f'Lengths of sentences 1: \n{s1_len}')
print(f'Lengths of sentences 2: \n{s2_len}')
# Out:
# Lengths of sentences 1:
# 0       22
# 1       31
# 2       45
# 3       28
# 4       27
#         ..
# 1374    53
# 1375    50
# 1376    42
# 1377    58
# 1378    41
# Name: sentence1, Length: 8628, dtype: int64
# Lengths of sentences 2:
# 0       27
# 1       25
# 2       56
# 3       26
# 4       34
#         ..
# 1374    39
# 1375    58
# 1376    59
# 1377    58
# 1378    56
# Name: sentence2, Length: 8628, dtype: int64

# %% [markdown]
# Average length of sentences:

# %%
avg_s1_len = s1_len.mean()
avg_s2_len = s2_len.mean()

print(f'Avg length of sentence 1: {avg_s1_len}')
print(f'Avg length of sentence 2: {avg_s2_len}')
# Out:
# Avg length of sentence 1: 58.23528048215113
# Avg length of sentence 2: 57.9598980064905

# %% [markdown]
# Processing sentences to extract vocabulary:

# %%
df_processed = pd.DataFrame(columns=['sentence1', 'sentence2', 'vocab1', 'vocab2'])

# lowercase
df_processed['sentence1'] = df['sentence1'].apply(lambda x : x.lower())
df_processed['sentence2'] = df['sentence2'].apply(lambda x : x.lower())

df_processed['vocab1'] = df_processed['sentence1'].apply(lambda x: sorted(str(x).split()))
df_processed['vocab2'] = df_processed['sentence2'].apply(lambda x: sorted(str(x).split()))

# %%
df_processed
# Out:
#                                               sentence1
# 0                                a plane is taking off.  \
# 1                       a man is playing a large flute.
# 2         a man is spreading shreded cheese on a pizza.
# 3                          three men are playing chess.
# 4                           a man is playing the cello.
# ...                                                 ...
# 1374  philippines, canada pledge to further boost re...
# 1375  israel bars palestinians from jerusalem's old ...
# 1376         how much do you know about secret service?
# 1377  obama struggles to soothe saudi fears as iran ...
# 1378          south korea declares end to mers outbreak
#
#                                               sentence2
# 0                           an air plane is taking off.  \
# 1                             a man is playing a flute.
# 2     a man is spreading shredded cheese on an uncoo...
# 3                            two men are playing chess.
# 4                    a man seated is playing the cello.
# ...                                                 ...
# 1374            philippines saves 100 after ferry sinks
# 1375  two-state solution between palestinians, israe...
# 1376  lawmakers from both sides express outrage at s...
# 1377  myanmar struggles to finalize voter lists for ...
# 1378  north korea delegation meets with south korean...
#
#                                                  vocab1
# 0                          [a, is, off., plane, taking]  \
# 1               [a, a, flute., is, large, man, playing]
# 2     [a, a, cheese, is, man, on, pizza., shreded, s...
# 3                    [are, chess., men, playing, three]
# 4                    [a, cello., is, man, playing, the]
# ...                                                 ...
# 1374  [boost, canada, further, philippines,, pledge,...
# 1375  [bars, city, from, israel, jerusalem's, old, p...
# 1376  [about, do, how, know, much, secret, service?,...
# 1377  [as, fears, iran, obama, resume, saudi, soothe...
# 1378  [declares, end, korea, mers, outbreak, south, to]
#
#                                                  vocab2
# 0                    [air, an, is, off., plane, taking]
# 1                      [a, a, flute., is, man, playing]
# 2     [a, an, cheese, is, man, on, pizza., shredded,...
# 3                      [are, chess., men, playing, two]
# 4            [a, cello., is, man, playing, seated, the]
# ...                                                 ...
# 1374     [100, after, ferry, philippines, saves, sinks]
# 1375  [between, in, israel, palestinians,, pie, sky,...
# 1376  [at, both, express, from, lawmakers, outrage, ...
# 1377  [finalize, for, lists, myanmar, polls, struggl...
# 1378  [delegation, korea, korean, meets, north, offi...
#
# [8628 rows x 4 columns]

# %% [markdown]
# Average n° of words per sentence:

# %%
avg_vocab1_size = df_processed['vocab1'].apply(lambda x: len(x)).mean()
avg_vocab2_size = df_processed['vocab2'].apply(lambda x: len(x)).mean()

print(f'Avg length of vocab 1: {avg_vocab1_size}')
print(f'Avg length of vocab 2: {avg_vocab2_size}')
# Out:
# Avg length of vocab 1: 10.183704218822438
# Avg length of vocab 2: 10.159828465461288

# %% [markdown]
# Average n° of words per sentence without considering duplicates:

# %%
avg_vocab1 = df_processed['vocab1'].apply(lambda x: len(set(x))).mean()
avg_vocab2 = df_processed['vocab2'].apply(lambda x: len(set(x))).mean()

print(f'Avg length of vocab 1 (without duplicates): {avg_vocab1}')
print(f'Avg length of vocab 2 (without duplicates): {avg_vocab2}')
# Out:
# Avg length of vocab 1 (without duplicates): 9.59121464997682
# Avg length of vocab 2 (without duplicates): 9.568382012053778

# %% [markdown]
# Vocabulary analysis, removing punctuation:

# %%
import string
import re

regex = '[' + string.punctuation + ']'
print(regex)
# Out:
# [!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~]

# %%
df_processed['vocab1'] = df_processed['sentence1'].apply(lambda x: sorted(str(re.sub(regex, '', x)).split()))
df_processed['vocab2'] = df_processed['sentence2'].apply(lambda x: sorted(str(re.sub(regex, '', x)).split()))

# %%
df_processed['vocab1'].apply(lambda x: len(x)).mean() # avg n° of words per sentence1
# Out:
# 10.163885025498377

# %%
df_processed['vocab2'].apply(lambda x: len(x)).mean() # avg n° of words per sentence2
# Out:
# 10.142095503013445

# %% [markdown]
# Analysis of the Vocabulary of all sentences 1 and 2:

# %%
# entire vocabulary of sentences 1
global_vocab1 = df_processed['vocab1'].sum()
print(global_vocab1[:20])
print(f'Vocab 1 size: {len(global_vocab1)}')
# Out:
# ['a', 'is', 'off', 'plane', 'taking', 'a', 'a', 'flute', 'is', 'large', 'man', 'playing', 'a', 'a', 'cheese', 'is', 'man', 'on', 'pizza', 'shreded']
# Vocab 1 size: 87694

# %%
# entire vocabulary of sentences 2
global_vocab2 = df_processed['vocab2'].sum()
print(global_vocab2[:20])
print(f'Vocab 2 size: {len(global_vocab2)}')
# Out:
# ['air', 'an', 'is', 'off', 'plane', 'taking', 'a', 'a', 'flute', 'is', 'man', 'playing', 'a', 'an', 'cheese', 'is', 'man', 'on', 'pizza', 'shredded']
# Vocab 2 size: 87506

# %%
import nltk
counts1 = nltk.Counter(global_vocab1)
print(counts1)

counts2 = nltk.Counter(global_vocab2)
print(counts2)
# Out:
# Counter({'a': 5283, 'the': 3949, 'in': 2446, 'is': 2037, 'to': 1778, 'of': 1625, 'and': 1289, 'on': 1233, 'man': 852, 'for': 655, 'with': 650, 'at': 579, 'woman': 525, 'are': 516, 'two': 415, 'that': 405, 'you': 354, 'playing': 345, 'it': 345, 'an': 338, 'said': 338, 'dog': 335, 'was': 314, 'as': 313, 'from': 311, 'us': 282, 'by': 279, 'white': 263, 'not': 258, 'i': 253, 'black': 240, 'have': 229, 'people': 216, 'be': 213, 'up': 208, 'its': 203, 'percent': 197, 'or': 191, 'has': 186, 'into': 183, 'after': 182, 'killed': 181, 'this': 180, 'new': 180, 'his': 172, 'over': 159, 'he': 155, 'down': 149, 'water': 147, 'do': 147, 'girl': 143, 'will': 143, 'syria': 143, 'what': 140, 'running': 139, 'person': 138, 'one': 135, 'boy': 134, 'but': 131, 'were': 130, 'three': 124, 'sitting': 124, 'brown': 122, 'had': 119, 'standing': 118, 'china': 118, 'riding': 117, 'police': 117, 'some': 116, 'guitar': 116, 'red': 116, 'more': 116, 'through': 113, 'about': 113, 'out': 112, 'there': 112, 'no': 112, 'cat': 109, 'dogs': 108, 'president': 105, 'against': 104, 'young': 104, 'group': 103, 'her': 102, 'would': 101, 'can': 98, 'grass': 97, 'we': 97, 'kills': 95, 'train': 94, 'they': 92, 'all': 92, 'your': 92, 'first': 91, 'who': 91, 'men': 90, 'snow': 90, 'slicing': 90, 'dead': 90, 'field': 89, 'been': 89, 'other': 88, 'horse': 88, 'nuclear': 86, 'than': 82, 'million': 82, 'car': 81, 'talks': 81, 'iran': 81, 'their': 80, 'women': 78, 'small': 77, 'walking': 77, 'government': 77, 'front': 76, 'death': 76, 'which': 76, 'pakistan': 76, 'if': 75, 'also': 75, 'shares': 73, 'obama': 71, 'says': 70, 'attack': 70, 'off': 69, 'looking': 69, 'near': 69, 'blue': 68, 'south': 67, 'four': 66, 'kill': 66, 'russia': 66, 'jumping': 65, 'ball': 64, 'while': 64, 'table': 64, 'many': 64, 'last': 64, 'state': 64, 'cutting': 63, 'years': 63, 'large': 62, 'camera': 62, 'north': 62, 'next': 61, 'syrian': 61, 'egypt': 61, 'beach': 60, 'wearing': 60, 'answer': 60, 'dont': 60, 'could': 60, 'close': 59, 'israel': 59, 'may': 59, 'around': 58, 'another': 58, 'weapons': 58, 'dancing': 57, 'little': 57, 'building': 57, 'found': 57, 'index': 57, 'military': 56, 'year': 56, 'states': 56, 'points': 56, '2': 56, 'security': 56, 'bus': 55, 'fire': 55, 'know': 55, 'want': 55, 'un': 55, 'someone': 54, 'court': 54, 'stocks': 54, 'eating': 52, 'afghanistan': 52, 'street': 51, 'united': 51, 'so': 51, 'my': 51, 'least': 51, 'deal': 51, 'officials': 51, 'wednesday': 51, 'election': 51, 'think': 50, 'baby': 49, 'child': 49, 'should': 49, 'forces': 49, 'attacks': 49, 'cents': 49, 'arrested': 49, 'iraq': 49, 'russian': 49, 'strike': 49, 'plane': 48, 'being': 48, 'yes': 48, 'vote': 48, 'just': 48, 'say': 48, 'korea': 48, 'end': 47, 'stock': 47, 'holding': 46, 'room': 46, 'air': 46, 'before': 46, 'when': 46, 'world': 46, 'back': 45, 'under': 45, 'how': 45, 'billion': 45, 'monday': 45, 'tuesday': 45, 'chief': 45, 'bomb': 45, 'green': 44, 'open': 44, 'question': 44, 'told': 44, '10': 44, 'onion': 43, 'use': 43, 'nasdaq': 43, 'chinese': 43, 'dies': 43, 'road': 42, 'get': 42, 'she': 42, 'bird': 42, 'did': 42, 'any': 42, 'israeli': 42, 'york': 42, 'india': 42, 'crash': 42, 'bike': 41, 'outside': 41, 'like': 41, 'children': 41, 'five': 41, 'day': 41, 'city': 41, 'toll': 41, 'stated': 41, 'set': 40, 'time': 40, 'since': 40, 'higher': 40, 'report': 40, 'international': 40, 'oil': 39, 'swimming': 39, 'does': 39, 'need': 39, 'case': 39, 'company': 39, '5': 39, 'presidential': 39, 'foreign': 39, 'runs': 38, 'shooting': 38, 'along': 38, 'him': 38, 'most': 38, 'friday': 38, 'hospital': 38, 'protesters': 38, 'protests': 38, 'suicide': 38, 'nato': 38, 'potato': 37, 'plays': 37, 'them': 37, 'house': 37, 'very': 37, 'peace': 37, 'only': 37, 'leader': 37, 'mr': 37, 'drug': 37, 'minister': 37, 'piano': 36, 'used': 36, 'girls': 36, 'share': 36, 'several': 36, 'arms': 36, 'top': 36, 'during': 36, 'east': 36, '11': 36, 'pm': 36, '3': 36, 'week': 36, 'chemical': 36, 'afghan': 36, 'cow': 35, 'yellow': 35, 'workers': 3 ...
# Counter({'a': 5533, 'the': 3848, 'in': 2567, 'is': 2076, 'to': 1787, 'of': 1570, 'and': 1292, 'on': 1242, 'man': 876, 'with': 667, 'for': 643, 'at': 592, 'woman': 538, 'are': 519, 'two': 405, 'that': 381, 'it': 365, 'dog': 360, 'said': 355, 'you': 329, 'playing': 315, 'was': 312, 'as': 306, 'an': 295, 'from': 294, 'by': 281, 'us': 281, 'white': 276, 'i': 272, 'black': 238, 'not': 236, 'have': 225, 'its': 223, 'his': 204, 'be': 203, 'people': 197, 'has': 197, 'percent': 192, 'up': 184, 'killed': 180, 'new': 169, 'this': 167, 'into': 164, 'or': 159, 'after': 158, 'but': 155, 'he': 149, 'down': 148, 'over': 144, 'will': 143, 'water': 141, 'syria': 136, 'girl': 135, 'running': 134, 'boy': 133, 'were': 131, 'riding': 129, 'standing': 126, 'sitting': 123, 'do': 123, 'china': 123, 'person': 119, 'guitar': 116, 'red': 116, 'police': 115, 'had': 115, 'cat': 112, 'through': 112, 'dogs': 111, 'horse': 109, 'one': 109, 'president': 109, 'out': 108, 'what': 108, 'other': 107, 'some': 107, 'three': 105, 'brown': 105, 'no': 105, 'would': 104, 'more': 101, 'group': 99, 'there': 98, 'can': 97, 'they': 97, 'pakistan': 97, 'nuclear': 96, 'been': 96, 'slicing': 95, 'about': 95, 'grass': 94, 'also': 94, 'against': 93, 'we': 93, 'million': 93, 'her': 92, 'young': 92, 'who': 91, 'women': 90, 'dead': 88, 'first': 88, 'your': 87, 'car': 86, 'train': 86, 'field': 86, 'iran': 86, 'kills': 86, 'all': 84, 'walking': 82, 'talks': 81, 'attack': 81, 'snow': 80, 'if': 80, 'men': 79, 'than': 79, 'small': 77, 'dont': 76, 'which': 74, 'state': 74, 'wearing': 73, 'last': 73, 'cutting': 72, 'front': 72, 'their': 72, 'off': 71, 'green': 71, 'blue': 71, 'north': 71, 'syrian': 70, 'russia': 69, 'around': 67, 'near': 66, 'south': 65, 'table': 65, 'close': 65, 'street': 64, 'israel': 64, 'egypt': 64, 'baby': 63, 'points': 63, 'court': 63, 'death': 63, 'found': 62, 'shares': 62, 'next': 61, 'least': 61, 'kill': 61, 'government': 61, 'dancing': 60, 'looking': 60, 'bus': 60, 'when': 60, 'weapons': 60, 'deal': 60, 'while': 59, 'four': 59, 'obama': 59, 'stock': 59, 'korea': 59, 'say': 58, 'many': 58, 'says': 58, 'camera': 57, 'stocks': 57, 'security': 57, 'may': 56, 'year': 56, 'eating': 55, 'large': 55, 'think': 55, 'my': 55, 'could': 55, 'index': 55, 'iraq': 55, 'air': 54, 'little': 54, 'beach': 54, 'day': 54, 'world': 54, 'officials': 54, 'election': 52, 'being': 51, 'building': 51, 'time': 51, 'military': 51, 'chief': 51, 'russian': 51, 'un': 51, 'dies': 51, 'open': 50, 'afghanistan': 50, 'back': 49, 'ball': 49, 'bomb': 49, 'city': 49, 'how': 49, 'monday': 49, 'york': 49, 'child': 48, 'strike': 48, 'cents': 48, 'runs': 47, 'another': 47, 'under': 47, 'years': 47, 'holding': 46, 'she': 46, 'forces': 46, 'attacks': 46, 'states': 46, 'nasdaq': 46, 'shirt': 45, 'just': 45, 'stated': 45, 'potato': 44, 'talking': 44, 'house': 44, 'along': 44, 'bird': 44, 'outside': 44, 'children': 44, 'fire': 44, 'want': 44, 'case': 44, 'plane': 43, 'room': 43, 'stands': 43, 'yellow': 43, 'only': 43, 'should': 43, 'like': 43, 'since': 43, 'hospital': 43, 'presidential': 43, 'someone': 42, 'jumping': 42, 'so': 42, 'wednesday': 42, 'india': 42, 'road': 41, 'oil': 41, 'several': 41, 'top': 41, 'palestinian': 41, '10': 41, 'arrested': 41, 'get': 40, 'sheep': 40, 'law': 40, 'friday': 40, 'week': 40, 'vote': 40, 'shooting': 39, 'before': 39, 'play': 39, 'opposition': 39, 'company': 39, 'pm': 39, 'israeli': 39, 'thursday': 39, 'united': 39, '3': 39, 'minister': 39, '2': 39, 'chemical': 39, 'nato': 39, 'afghan': 39, 'arms': 38, 'wall': 38, 'area': 38, 'laying': 38, 'question': 38, '1': 38, 'foreign': 38, 'crash': 38, 'chinese': 38, 'bowl': 37, 'them': 37, 'between': 37, 'five': 37, 'problem': 37, 'billion': 37, 'did': 37, 'need': 37, 'lower': 37, 'leader': 37, '12': 37, 'protesters': 37, 'international': 37, 'singing': 36, 'across': 36, 'driving': 36, 'answer': 36, 'know': 36, 'second': 36, 'mr': 36, 'british': 36, 'tuesday': 36, 'very': 35, 'work': 35, 'background': 35, 'set': 35, 'yesterday': 35, ' ...

# %%
counts1.most_common(30)
# Out:
# [('a', 5283),
#  ('the', 3949),
#  ('in', 2446),
#  ('is', 2037),
#  ('to', 1778),
#  ('of', 1625),
#  ('and', 1289),
#  ('on', 1233),
#  ('man', 852),
#  ('for', 655),
#  ('with', 650),
#  ('at', 579),
#  ('woman', 525),
#  ('are', 516),
#  ('two', 415),
#  ('that', 405),
#  ('you', 354),
#  ('playing', 345),
#  ('it', 345),
#  ('an', 338),
#  ('said', 338),
#  ('dog', 335),
#  ('was', 314),
#  ('as', 313),
#  ('from', 311),
#  ('us', 282),
#  ('by', 279),
#  ('white', 263),
#  ('not', 258),
#  ('i', 253)]

# %%
counts2.most_common(30)
# Out:
# [('a', 5533),
#  ('the', 3848),
#  ('in', 2567),
#  ('is', 2076),
#  ('to', 1787),
#  ('of', 1570),
#  ('and', 1292),
#  ('on', 1242),
#  ('man', 876),
#  ('with', 667),
#  ('for', 643),
#  ('at', 592),
#  ('woman', 538),
#  ('are', 519),
#  ('two', 405),
#  ('that', 381),
#  ('it', 365),
#  ('dog', 360),
#  ('said', 355),
#  ('you', 329),
#  ('playing', 315),
#  ('was', 312),
#  ('as', 306),
#  ('an', 295),
#  ('from', 294),
#  ('by', 281),
#  ('us', 281),
#  ('white', 276),
#  ('i', 272),
#  ('black', 238)]

# %% [markdown]
# Removing stopwords:

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\simon\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# vocab 1 without stopwords
vocab1_nostop = [w for w in global_vocab1 if w not in stopwords.words('english')]
counts1_nostop = nltk.Counter(vocab1_nostop)

# %%
# vocab 2 without stopwords
vocab2_nostop = [w for w in global_vocab2 if w not in stopwords.words('english')]
counts2_nostop = nltk.Counter(vocab2_nostop)

# %%
counts1_nostop.most_common(30)
# Out:
# [('man', 852),
#  ('woman', 525),
#  ('two', 415),
#  ('playing', 345),
#  ('said', 338),
#  ('dog', 335),
#  ('us', 282),
#  ('white', 263),
#  ('black', 240),
#  ('people', 216),
#  ('percent', 197),
#  ('killed', 181),
#  ('new', 180),
#  ('water', 147),
#  ('girl', 143),
#  ('syria', 143),
#  ('running', 139),
#  ('person', 138),
#  ('one', 135),
#  ('boy', 134),
#  ('three', 124),
#  ('sitting', 124),
#  ('brown', 122),
#  ('standing', 118),
#  ('china', 118),
#  ('riding', 117),
#  ('police', 117),
#  ('guitar', 116),
#  ('red', 116),
#  ('cat', 109)]

# %%
counts2_nostop.most_common(30)
# Out:
# [('man', 876),
#  ('woman', 538),
#  ('two', 405),
#  ('dog', 360),
#  ('said', 355),
#  ('playing', 315),
#  ('us', 281),
#  ('white', 276),
#  ('black', 238),
#  ('people', 197),
#  ('percent', 192),
#  ('killed', 180),
#  ('new', 169),
#  ('water', 141),
#  ('syria', 136),
#  ('girl', 135),
#  ('running', 134),
#  ('boy', 133),
#  ('riding', 129),
#  ('standing', 126),
#  ('sitting', 123),
#  ('china', 123),
#  ('person', 119),
#  ('guitar', 116),
#  ('red', 116),
#  ('police', 115),
#  ('cat', 112),
#  ('dogs', 111),
#  ('horse', 109),
#  ('one', 109)]

# %% [markdown]
# Vocabulary of entire dataset:

# %%
global_vocab = global_vocab1 + global_vocab2
print(f'Vocabulary size: {len(global_vocab)}')
# Out:
# Vocabulary size: 175200

# %%
counts = nltk.Counter(global_vocab)

# %%
counts.most_common(30)
# Out:
# [('a', 10816),
#  ('the', 7797),
#  ('in', 5013),
#  ('is', 4113),
#  ('to', 3565),
#  ('of', 3195),
#  ('and', 2581),
#  ('on', 2475),
#  ('man', 1728),
#  ('with', 1317),
#  ('for', 1298),
#  ('at', 1171),
#  ('woman', 1063),
#  ('are', 1035),
#  ('two', 820),
#  ('that', 786),
#  ('it', 710),
#  ('dog', 695),
#  ('said', 693),
#  ('you', 683),
#  ('playing', 660),
#  ('an', 633),
#  ('was', 626),
#  ('as', 619),
#  ('from', 605),
#  ('us', 563),
#  ('by', 560),
#  ('white', 539),
#  ('i', 525),
#  ('not', 494)]

# %%
vocab_nostopwords = [w for w in global_vocab if w not in stopwords.words('english')]
counts_nostopwords = nltk.Counter(vocab_nostopwords)

# %%
counts_nostopwords.most_common(30)
# Out:
# [('man', 1728),
#  ('woman', 1063),
#  ('two', 820),
#  ('dog', 695),
#  ('said', 693),
#  ('playing', 660),
#  ('us', 563),
#  ('white', 539),
#  ('black', 478),
#  ('people', 413),
#  ('percent', 389),
#  ('killed', 361),
#  ('new', 349),
#  ('water', 288),
#  ('syria', 279),
#  ('girl', 278),
#  ('running', 273),
#  ('boy', 267),
#  ('person', 257),
#  ('sitting', 247),
#  ('riding', 246),
#  ('one', 244),
#  ('standing', 244),
#  ('china', 241),
#  ('guitar', 232),
#  ('red', 232),
#  ('police', 232),
#  ('three', 229),
#  ('brown', 227),
#  ('cat', 221)]
